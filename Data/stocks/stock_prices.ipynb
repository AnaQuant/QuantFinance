# %%
# !pip install mplfinance
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from datetime import datetime
import yfinance as yf
import mplfinance as mpf

# %%
start_date = datetime(2019, 1, 1)
end_date = datetime(2020, 12, 31)
data = yf.download('NVDA', start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['NVDA']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  37.708595  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  33.952549  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.401951  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.323154  219111200
# 2019-01-08  37.389999  37.955002  37.130001  37.687500  35.996529  164101200

# %%
mpf.plot(data,type='candle',mav=(3,6,9),volume=True,show_nontrading=True)

# %% [markdown]
# ## FX and Crypto

# %%
data = yf.download('EURUSD=X', start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2019-01-01  1.149425  1.155001  1.146500  1.149306   1.149306       0
# 2019-01-02  1.146132  1.149700  1.134572  1.146171   1.146171       0
# 2019-01-03  1.131734  1.140914  1.131734  1.131811   1.131811       0
# 2019-01-04  1.139095  1.141774  1.134816  1.139108   1.139108       0
# 2019-01-07  1.141292  1.147447  1.140524  1.141044   1.141044       0

# %%
btc = yf.download('BTC-USD', start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
mpf.plot(btc,type='line',volume=True,show_nontrading=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %config InlineBackend.figure_format ='retina'
sns.set(style="whitegrid")

# %%
ir_df = yf.download('^FVX')
plt.figure(figsize=(12, 6))
ir_df['Close'].plot(color='green', title="Treasury Yield 5 Years")
plt.show()
# Out:
# Failed to get ticker '^FVX' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['^FVX']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
