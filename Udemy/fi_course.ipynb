# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('..')  # Add parent directory to access packages

from datetime import datetime

# %%
import FixedIncome.FIA as FIA

# %%
bond = FIA.create_coupon_bond(maturity=10, face=10000, rate=4, frequency=1)

# %%
tnote = FIA.create_coupon_bond(maturity=5, face=100, rate=3, frequency=2)

# %%
zero = FIA.create_coupon_bond(maturity=7, face=50000, frequency=0)

# %%
bond.get_cashflows()
# Out:
# [400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 10400.0]

# %%
bond.plot_payments()

# %%
yc = FIA.create_flat_curve(4, compounding=1)

# %%
yc.get_rates()
# Out:
# [3.922071315328133]

# %%
yc.spot_rate(5, compounding=2)
# Out:
# 3.9607805437114063
